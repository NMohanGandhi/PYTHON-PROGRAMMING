# %%
# import essential libraries
import numpy as np
import pandas as pd

# %%
# Create a pandas series
# by using list create series
li = [1,2,3,4,5]
df = pd.Series(li)
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ![Descriptionh](C:/Users/mohan/Desktop/Screenshot 2024-11-08 065812.png)

# %% [markdown]
# ![My Screenshot](C:/Users/mohan/Pictures/Screenshots/Screenshot%202024-11-08%20065812.png)

# %% [markdown]
# ![Description](C:/Users/mohan/Desktop/Screenshot%202024-11-08%20065812.png)
