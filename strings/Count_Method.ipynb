# %% [markdown]
# # Counting substring in the given string

# %%
name = "My name is prathima"

# %%
name.count('a')
# Out:
# 3

# %%
name.count(' ')
# Out:
# 3

# %%
name.count('M')
# Out:
# 1

# %%
name.count('m')
# Out:
# 2

# %%
w = "ABCBABCCDEFGGBB"

# %%
w.count('A')
# Out:
# 2

# %%
w.count('AB')
# Out:
# 2

# %%
w.count('BB')
# Out:
# 1

# %%
w.count('ABC')
# Out:
# 2

# %% [raw]
# WRITE A PROGRAM TO FIND ALL THE OCCURANCE INDEX POSITION OF THE SUBSTRING

# %%
# Method 1 for understanding

# %%
s = 'ABCABCABCA'  # THIS IS A  MAIN STRING

# %%
len(s) # len of string is 10
# Out:
# 10

# %%
sub = 'ABC'     # THIS IS A SUB STRING

# %%
# FIRSTLY WE NEED TO CHECK SUBSTRING IS AVAILABLE ARE NOT IN THE MAIN STRING
#IF IT IS AVAILABLE GO A HEAD ELSE IT RETURNS -1

# %%
i = s.find(sub)
i
# Out:
# 0

# %%
# substring found at index ""zero""  then we need find remaining substrings
#where found in the main string

# %%
len(sub)
# Out:
# 3

# %%
i1 = s.find('ABC',3,len(s)) # skip the len of substring 3 so we start next checking 3,
i1
# Out:
# 3

# %%
i2 = s.find('ABC',6,len(s)-1) 
i2
# Out:
# 6

# %%
i2 = s.find('ABC',9,len(s)) 
i2
# Out:
# -1

# %%
S = input("Enter your main string")
# Out:
# Enter your main string ABCABCABCA

# %%
S
# Out:
# 'ABCABCABCA'

# %%
Sub = input("Enter your subString")
Sub
# Out:
# Enter your subString ABC
# 'ABC'

# %%
# we need check substring is found or not in main string

# %%
i = S.find(Sub)
i
# Out:
# 0

# %%
if i==-1:
    print("Substring not found")
while i !=-1:
    print("Substring is there find it indexes")
    print("{} present at index {}".format(Sub,i))
    i = S.find(Sub,i+len(Sub),len(S))
print("The count of {} is {}".format(Sub,S.count(Sub)))
# Out:
# Substring is there find it indexes
# ABC present at index 0
# Substring is there find it indexes
# ABC present at index 3
# Substring is there find it indexes
# ABC present at index 6
# The count of ABC is 3

# %% [raw]
# The original string is : GeeksforGeeks is best for Geeks
# The substring to find : Geeks

# %%
origina_string =  "GeeksforGeeks is best for Geeks"
substring  = "Geeks"

# %%
i = origina_string.find(substring)
i
# Out:
# 0

# %%
if i==-1:
    print("Substring not found")
while i !=-1:
    print("Substring is there find it indexes")
    print("{} is presented in index of {}".format(substring,i))
    i=origina_string.find(substring,i+len(substring),len(origina_string))
print("The count of {} is {}".format(substring,origina_string.count(substring)))
# Out:
# Substring is there find it indexes
# Geeks is presented in index of 0
# Substring is there find it indexes
# Geeks is presented in index of 8
# Substring is there find it indexes
# Geeks is presented in index of 26
# The count of Geeks is 3

# %%
def find_all_substrings(string, substring):
    # Initialize an empty list to store the 
    # indices of all occurrences of the substring.
    indices = []
    # Set the starting index i to 0.
    i = 0
    # Use a while loop to keep searching for 
    # the substring in the string.
    while i < len(string):
        # Use the find() method to find the first 
        #occurrence of the substring in the string
        j = string.find(substring, i)
        # If find() returns -1, it means that there  
        # are no more occurrences of the substring in 
        # the string, so break out of the loop.
        if j == -1:
            break
        indices.append(j)
        i = j + len(substring)
    # Return the list of indices.
    return indices
 
# Example usage:
test_str = "GeeksforGeeks is best for Geeks"
test_sub = "Geeks"
print(find_all_substrings(test_str, test_sub))
# Out:
# [0, 8, 26]

# %%
test_str = "GeeksforGeeks is best for Geeks"
 
# initializing substring
test_sub = "Geeks"
 
# printing original string
print("The original string is : " + test_str)
 
# printing substring
print("The substring to find : " + test_sub)
 
# using list comprehension + startswith()
# All occurrences of substring in string
res = [i for i in range(len(test_str)) if test_str.startswith(test_sub, i)]
 
# printing result
print("The start indices of the substrings are : " + str(res))
# Out:
# The original string is : GeeksforGeeks is best for Geeks
# The substring to find : Geeks
# The start indices of the substrings are : [0, 8, 26]
