# %% [raw]
# write a program to check whether provided username and password are valid or not?
# username is not case sensitive and password should be case sensitive

# %%
username = input()
password = input()
# Out:
#  mohan@gmail.com
#  12345ihde

# %%
if (username.lower() == "mohan@gmail.com") and (password == "12345nN##"):
    print("grand access")
else:
    print("Invalid")
# Out:
# Invalid
