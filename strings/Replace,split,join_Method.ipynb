# %% [markdown]
# # Reduce

# %%
s = 'ABABBA'

# %%
print("Before replacing",id(s))
# Out:
# Before replacing 2015406010464

# %%
s1 = s.replace("A","b")
s1
# Out:
# 'bBbBBb'

# %%
print("After replacing",id(s1))
# Out:
# After replacing 2015404895248

# %%
arr = "Python is very difficult language"

# %%
arr.replace("difficult","Easy")
# Out:
# 'Python is very Easy language'

# %%
arr.count(" ")
# Out:
# 4

# %%
arr.replace(" ","")
# Out:
# 'Pythonisverydifficultlanguage'

# %%
arr.replace(" ","-")
# Out:
# 'Python-is-very-difficult-language'

# %% [markdown]
# # Split()

# %%
print("Mohan gandhi".split())
# Out:
# ['Mohan', 'gandhi']

# %%
print("Mohan-gandhi".split())
# Out:
# ['Mohan-gandhi']

# %%
print("Mohan-gandhi".split("-"))
# Out:
# ['Mohan', 'gandhi']

# %%
s = "Durga software solutions"

# %%
l = s.split() 
l# default it takes space parameter
# Out:
# ['Durga', 'software', 'solutions']

# %%
print("Durgasoftware solutions".split())
# Out:
# ['Durgasoftware', 'solutions']

# %%
print("Durgasoftwaresolutions".split())
# Out:
# ['Durgasoftwaresolutions']

# %%
# split anuthing it returns list type

# %%
for x in l:
    print(x)
# Out:
# Durga
# software
# solutions

# %%
d = '12/02/2023'.split("/")
d
# Out:
# ['12', '02', '2023']

# %%
d1 = 12-02-7292.split("-")
d1
# Out:
#   Cell In[30], line 1
#     d1 = 12-02-7292.split("-")
#             ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
d1 = "12-02-7292".split("-")
d1
# Out:
# ['12', '02', '7292']

# %% [markdown]
# # join()

# %%
"".join(d1)
# Out:
# '12027292'

# %%
"-".join(d1)
# Out:
# '12-02-7292'

# %%
"".join(l)
# Out:
# 'Durgasoftwaresolutions'

# %%
" ".join(l)
# Out:
# 'Durga software solutions'

# %%
"-".join(l)
# Out:
# 'Durga-software-solutions'

# %%
L = ['a',1,'1.5']

# %%
" ".join(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 " ".join(L)
#
# TypeError: sequence item 1: expected str instance, int found

# %%
L1 = ['a','1','1.5']

# %%
" ".join(L1)
# Out:
# 'a 1 1.5'

# %%
"".join(L1)
# Out:
# 'a11.5'

# %%
l3 = [1,2,3]

# %%
" ".join(l3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 " ".join(l3)
#
# TypeError: sequence item 0: expected str instance, int found
